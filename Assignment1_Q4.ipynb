# %% [markdown]
# # Question 4
#
# - Read all content of files from nps_chat corpora
# - Display the count of chats posted by user121
# - Display number of unique users in each age group

# %%
import nltk
from nltk.corpus import nps_chat

# %%
corpus_list = nltk.corpus.nps_chat

# %%
type(corpus_list)
#corpus_list
# Out:
# nltk.corpus.reader.nps_chat.NPSChatCorpusReader

# %%
# Getting post data from all nps_chat files.
xml = corpus_list.xml_posts()

#Looping through xml data to find User121.
usr = 0
for p in xml:
    if p.get('user').endswith('User121'):
        usr = usr + 1
print('Total post posted by User121 are : ', usr)
# Out:
# Total post posted by User121 are :  132

# %%
user_age_list = []
for x in  nltk.corpus.nps_chat.fileids():
    #xmldoc = minidom.parse(path+x)
    #itemlist = xmldoc.getElementsByTagName('Post')
    for s in itemlist:
        user_age_list.append(s.attributes['user'].value)
print(user_age_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-178-d13fd157d413> in <module>()
#       4     #itemlist = xmldoc.getElementsByTagName('Post')
#       5     for s in xml:
# ----> 6         user_age_list.append(s.attributes['user'].value)
#       7 print(user_age_list)
#
# AttributeError: 'xml.etree.ElementTree.Element' object has no attribute 'attributes'

# %%
#Accessing all the text of the corpus
all_text = nltk.corpus.nps_chat.raw()

print('total words in all files =', len(all_text))

type(all_text)
#print (all_text)
# Out:
# total words in all files = 2568552
# str

# %%
#Accessing the name of the files of the corpus

files=nltk.corpus.nps_chat.fileids()

#getting all the characters in all the files
#int z =0
for f in files:
    #print (f)
    w = nltk.corpus.nps_chat.raw(f)
    print('content in one file=', len(w))
    
print('total content in all files=', len(all_text))
# Out:
# content in one file= 161224
# content in one file= 178943
# content in one file= 172138
# content in one file= 198219
# content in one file= 171376
# content in one file= 183327
# content in one file= 163314
# content in one file= 165795
# content in one file= 155794
# content in one file= 179860
# content in one file= 150146
# content in one file= 178554
# content in one file= 189178
# content in one file= 161983
# content in one file= 158701
# total content in all files= 2568552

# %%
#counter = 0
#for word in all_text:
  #  if word == 'who':
#     counter += 1

# %%
#counter

# %%
#files
#check = nltk.corpus.nps_chat.words('11-08-teens_706posts.xml')

# %%
#check

# %%
#counter = {}
#for word in check:
#    if word in counter:
#        counter[word] +=1
#    else:
 #        counter[word] = 1

# %%
#counter {}
#if 'sounds' in check:
   # global counter
    #counter= counter + 1

# %%
#counter

# %%
#for word in check:
#if 'user121' in check: 
#       print('success')

# %%
#from collections import Counter

#check = input_string.split()
#wordCount = Counter(check)

# %%
#from nltk.corpus import PlaintextCorpusReader as pcr

# %%
#mycorpus = pcr(nps_chat, r'.*\.txt')

#for fname in mycorpus.fileids():
#    text = mycorpus.raw(fname)
#    sents = mycorpus.sents(fname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b93dcc9b72fc> in <module>()
# ----> 1 mycorpus = pcr(nps_chat, r'.*\.txt')
#       2
#       3 for fname in mycorpus.fileids():
#       4     text = mycorpus.raw(fname)
#       5     sents = mycorpus.sents(fname)
#
# NameError: name 'nps_chat' is not defined

# %%
#def main():
 #   cor = corpus()
    # for every text file in the corpus:
        #Do this method

#def corpus():
 #   corpus_root=nltk.corpus.nps_chat.fileids()
    #   corp = pcr(corpus_root,'.*\.txt')
     #   corp = corp.raw()
#  return corp

#main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-16b948c0b86e> in <module>()
#      10     return corp
#      11
# ---> 12 main()
#
# <ipython-input-1-16b948c0b86e> in main()
#       1 def main():
# ----> 2     cor = corpus()
#       3     # for every text file in the corpus:
#       4         #Do this method
#       5
#
# <ipython-input-1-16b948c0b86e> in corpus()
#       5
#       6 def corpus():
# ----> 7     corpus_root=nltk.corpus.nps_chat.fileids()
#       8     corp = pcr(corpus_root,'.*\.txt')
#       9     corp = corp.raw()
#
# NameError: name 'nltk' is not defined
