# %% [markdown]
# # Question 2
#
# Part 1
# - Reading all json files from Data folder.
# - Seperate all json files based on their type (Hotel, Restaurants and Attractions)
# - Create three different folders to store these files based on their type

# %%
#creating a list containing all json files
import glob
json_files = glob.glob("/Users/jha_anamika/Downloads/DataAnalysis4Python_Spring17-master/Assignment2/Data/*.json")

# %%
#type(files)
#len(json_files)
#json_files

# %%
#printing the json file to get better idea of the content
import json
from pprint import pprint

with open('/Users/jha_anamika/Downloads/DataAnalysis4Python_Spring17-master/Assignment2/Data/10-downing-street-london.json') as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# {'categories': [{'alias': 'publicservicesgovt',
#                  'title': 'Public Services & Government'}],
#  'coordinates': {'latitude': 51.5033668727612, 'longitude': -0.127591834760465},
#  'id': '10-downing-street-london',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tBaN642q9-xy6V2-Q3e78A/o.jpg',
#  'is_claimed': False,
#  'is_closed': False,
#  'location': {'address1': '10 Downing Street',
#               'address2': '',
#               'address3': '',
#               'city': 'London',
#               'country': 'GB',
#               'state': 'XGL',
#               'zip_code': 'SW1A 2AB'},
#  'name': '10 Downing Street',
#  'phone': '+442079250918',
#  'photos': ['https://s3-media2.fl.yelpcdn.com/bphoto/tBaN642q9-xy6V2-Q3e78A/o.jpg',
#             'https://s3-media3.fl.yelpcdn.com/bphoto/NMGJysMeq3_xwYAeaZmYRQ/o.jpg',
#             'https://s3-media2.fl.yelpcdn.com/bphoto/o_-Xn_oTpvqJyjDauL7S2Q/o.jpg'],
#  'rating': 3.0,
#  'review_count': 32,
#  'term': 'attractions',
#  'url': 'https://www.yelp.com/biz/10-downing-street-london?adjust_creative=92p07_JjKyriZTQxAXRiKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=92p07_JjKyriZTQxAXRiKQ'}

# %%
#diving the files based on different key terms
term_rest = []
term_att = []
term_hotel = []
for file in json_files:
    with open(file) as data_file:
        data = json.load(data_file)
        if data['term'] == 'hotels':
            term_hotel.append(data)
        if data['term'] == 'restaurants':
            term_rest.append(data)
        if data['term'] == 'attractions':
            term_att.append(data)

# %%
len(term_hotel)
#term_rest
# Out:
# 2182

# %%
country = []
for a in term_rest:
    with open(file) as data_file:    
        data = json.load(data_file)
        country.append(data['location']['country'])

# %%
set(country)
# Out:
# {'FR'}
