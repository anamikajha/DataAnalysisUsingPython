# %% [markdown]
# # Question 2
# Part 2
# - Read only the json files which contain the key called “restaurants”
# - Each (or most of the json files) contain a key called “open” which contains the details of the operation (timings) of the restaurants. For each json file, read the timings of the restaurants.
# - Data of the operation timings of the restaurants is present for each day of the week. I want you to extract each of this data and write it in an excel sheet.

# %%
#importing file using glob function
import glob
import json
json_files = glob.glob("Data/*.json")

#Reading only the files which have a value of restaurants
restaurants=[]
for file in json_files:
    with open(file) as data_file:    
        data = json.load(data_file)
        if data['term']=="restaurants":
            restaurants.append(file)

# %%
#Extracting data from the file and writing it into the csv file
import csv
with open("Restaurant.csv","w",encoding='utf-8') as myfile:
    writer = csv.writer(myfile, delimiter=",", quotechar="|", quoting=csv.QUOTE_MINIMAL, lineterminator='\n')
    writer.writerow(["Name of Restaurant","City","Country Code","Day of Week","Start Time Hour","Start Time Minute","End Time Hour","End Time Minute"])
    for file in restaurants:
        with open(file) as data_file:    
            data = json.load(data_file)
            try: 
                for i in range(0,len(data['hours'][0]['open'])):
                    writer.writerow([data['id'],data['location']['city'],data['location']['country'],data['hours'][0]['open'][i]['day'],data['hours'][0]['open'][i]['start'][:2],data['hours'][0]['open'][i]['start'][-2:],data['hours'][0]['open'][i]['end'][:2],data['hours'][0]['open'][i]['end'][-2:]])
            except KeyError:
                pass

# %%
#creating a list containing all json files
import glob
json_files = glob.glob("Data/*.json")

# %%
#diving the files based on different key terms
import json
term_rest = []
for file in json_files:
    with open(file) as data_file:
        data = json.load(data_file)
        if data['term'] == 'restaurants':
            term_rest.append(data)

# %%
count= []
for a in term_rest:
     count.append(a['location']['country'])
count = set(count)


d= []
for a in term_rest:
    for b in count:
        if a['location']['country'] == b:
            case = {b: a['location']['city']}
            d.append(case)

# %%
d
# Out:
# [{'AU': 'Sydney'},
#  {'US': 'Houston'},
#  {'US': 'San Jose'},
#  {'AU': 'Braddon'},
#  {'GB': 'London'},
#  {'US': 'Denver'},
#  {'GB': 'London'},
#  {'AU': 'Melbourne'},
#  {'GB': 'Glasgow'},
#  {'AU': 'Brisbane'},
#  {'US': 'Phoenix'},
#  {'GB': 'Glasgow'},
#  {'AU': 'Perth'},
#  {'US': 'San Francisco'},
#  {'US': 'Boston'},
#  {'US': 'San Francisco'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Perth'},
#  {'AU': 'Sydney'},
#  {'US': 'Detroit'},
#  {'US': 'Washington'},
#  {'AU': 'Belconnen'},
#  {'US': 'San Francisco'},
#  {'US': 'Charlotte'},
#  {'US': 'Denver'},
#  {'US': 'New York'},
#  {'US': 'Detroit'},
#  {'AU': 'Perth'},
#  {'GB': 'London'},
#  {'US': 'New York'},
#  {'US': 'Chicago'},
#  {'US': 'Houston'},
#  {'US': 'Long Island City'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'US': 'Phoenix'},
#  {'AU': 'Sydney'},
#  {'US': 'Houston'},
#  {'AU': 'Kingston'},
#  {'AU': 'Melbourne'},
#  {'AU': "O'connor"},
#  {'US': 'San Francisco'},
#  {'GB': 'London'},
#  {'AU': 'Surry Hills'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Brisbane'},
#  {'US': 'Chicago'},
#  {'US': 'Boston'},
#  {'US': 'Seattle'},
#  {'US': 'Charlotte'},
#  {'US': 'Las Vegas'},
#  {'US': 'Denver'},
#  {'US': 'Denver'},
#  {'AU': 'Melbourne'},
#  {'US': 'Charlotte'},
#  {'AU': 'Sydney'},
#  {'AU': 'Sydney'},
#  {'US': 'Seattle'},
#  {'US': 'Detroit'},
#  {'US': 'Denver'},
#  {'US': 'Denver'},
#  {'US': 'Boston'},
#  {'AU': 'Canberra'},
#  {'US': 'Charlotte'},
#  {'GB': 'London'},
#  {'US': 'Las Vegas'},
#  {'US': 'Houston'},
#  {'AU': 'Melbourne'},
#  {'US': 'San Jose'},
#  {'US': 'Seattle'},
#  {'US': 'Chicago'},
#  {'US': 'Chicago'},
#  {'AU': 'Melbourne'},
#  {'US': 'Houston'},
#  {'US': 'Detroit'},
#  {'US': 'Washington'},
#  {'US': 'San Jose'},
#  {'AU': 'Chifley'},
#  {'AU': 'Inglewood'},
#  {'US': 'San Jose'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Brisbane'},
#  {'AU': 'Sydney'},
#  {'US': 'Boston'},
#  {'US': 'New York'},
#  {'US': 'Boston'},
#  {'AU': 'Manuka'},
#  {'GB': 'London'},
#  {'US': 'Washington'},
#  {'GB': 'London'},
#  {'US': 'Las Vegas'},
#  {'US': 'Denver'},
#  {'AU': 'Melbourne'},
#  {'GB': 'Glasgow'},
#  {'US': 'Houston'},
#  {'GB': 'Liverpool'},
#  {'GB': 'London'},
#  {'US': 'Phoenix'},
#  {'US': 'Denver'},
#  {'US': 'San Jose'},
#  {'AU': 'Perth'},
#  {'GB': 'London'},
#  {'US': 'Phoenix'},
#  {'AU': 'Sydney'},
#  {'AU': 'Melbourne'},
#  {'US': 'Houston'},
#  {'GB': 'London'},
#  {'US': 'San Jose'},
#  {'US': 'San Jose'},
#  {'US': 'Denver'},
#  {'US': 'Houston'},
#  {'AU': 'Braddon'},
#  {'AU': 'Perth'},
#  {'US': 'Brooklyn'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Brisbane'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'GB': 'London'},
#  {'GB': 'Glasgow'},
#  {'US': 'Boston'},
#  {'GB': 'London'},
#  {'US': 'Houston'},
#  {'US': 'Detroit'},
#  {'GB': 'Glasgow'},
#  {'US': 'Boston'},
#  {'US': 'Houston'},
#  {'US': 'Brooklyn'},
#  {'AU': 'Dickson'},
#  {'NZ': 'Auckland'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'US': 'Las Vegas'},
#  {'US': 'Denver'},
#  {'GB': 'Liverpool'},
#  {'US': 'Washington'},
#  {'AU': 'Sydney'},
#  {'AU': 'Perth'},
#  {'US': 'Boston'},
#  {'AU': 'Canberra'},
#  {'AU': 'Sydney'},
#  {'US': 'Seattle'},
#  {'AU': 'Perth'},
#  {'US': 'Chicago'},
#  {'US': 'Washington'},
#  {'US': 'Detroit'},
#  {'US': 'Detroit'},
#  {'GB': 'London'},
#  {'US': 'San Jose'},
#  {'US': 'Brooklyn'},
#  {'GB': 'Liverpool'},
#  {'US': 'Las Vegas'},
#  {'GB': 'Liverpool'},
#  {'US': 'Las Vegas'},
#  {'GB': 'London'},
#  {'US': 'Denver'},
#  {'AU': 'Sydney'},
#  {'AU': 'Sydney'},
#  {'US': 'Birmingham'},
#  {'NZ': 'Auckland'},
#  {'US': 'Houston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'GB': 'Glasgow'},
#  {'US': 'Washington'},
#  {'AU': 'Acton'},
#  {'AU': 'Perth'},
#  {'US': 'Seattle'},
#  {'US': 'San Jose'},
#  {'US': 'San Jose'},
#  {'GB': 'London'},
#  {'AU': 'Sydney'},
#  {'US': 'Washington'},
#  {'US': 'Denver'},
#  {'US': 'Houston'},
#  {'US': 'Boston'},
#  {'US': 'Charlotte'},
#  {'US': 'Las Vegas'},
#  {'US': 'Detroit'},
#  {'US': 'Somerville'},
#  {'GB': 'Liverpool'},
#  {'US': 'Chicago'},
#  {'US': 'Seattle'},
#  {'US': 'Chicago'},
#  {'US': 'Denver'},
#  {'US': 'Chicago'},
#  {'US': 'Charlotte'},
#  {'AU': 'Melbourne'},
#  {'US': 'Chicago'},
#  {'US': 'Birmingham'},
#  {'US': 'New York'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Washington'},
#  {'US': 'Boston'},
#  {'US': 'Washington'},
#  {'US': 'Washington'},
#  {'US': 'Washington'},
#  {'NZ': 'Auckland'},
#  {'US': 'Houston'},
#  {'GB': 'Glasgow'},
#  {'US': 'Houston'},
#  {'US': 'Detroit'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'US': 'Las Vegas'},
#  {'US': 'Washington'},
#  {'US': 'Boston'},
#  {'GB': 'London'},
#  {'US': 'Boston'},
#  {'US': 'Detroit'},
#  {'US': 'Brooklyn'},
#  {'AU': 'Sydney'},
#  {'AU': 'Perth'},
#  {'US': 'Boston'},
#  {'US': 'New York'},
#  {'US': 'Detroit'},
#  {'US': 'San Jose'},
#  {'GB': 'London'},
#  {'US': 'Detroit'},
#  {'US': 'Phoenix'},
#  {'GB': 'London'},
#  {'US': 'Phoenix'},
#  {'US': 'Charlotte'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Houston'},
#  {'US': 'Boston'},
#  {'GB': 'London'},
#  {'US': 'San Jose'},
#  {'US': 'Chicago'},
#  {'US': 'Detroit'},
#  {'US': 'San Jose'},
#  {'US': 'Houston'},
#  {'US': 'San Francisco'},
#  {'AU': 'Melbourne'},
#  {'US': 'Houston'},
#  {'US': 'Washington'},
#  {'AU': 'Melbourne'},
#  {'GB': 'London'},
#  {'US': 'Denver'},
#  {'AU': 'The Rocks'},
#  {'US': 'Detroit'},
#  {'GB': 'London'},
#  {'AU': 'Perth'},
#  {'US': 'Charlotte'},
#  {'US': 'San Jose'},
#  {'US': 'San Jose'},
#  {'AU': 'Brisbane'},
#  {'US': 'Boston'},
#  {'US': 'San Jose'},
#  {'US': 'Boston'},
#  {'GB': 'London'},
#  {'US': 'Seattle'},
#  {'US': 'San Jose'},
#  {'US': 'Las Vegas'},
#  {'US': 'Detroit'},
#  {'US': 'Chicago'},
#  {'US': 'Chicago'},
#  {'US': 'San Jose'},
#  {'AU': 'Canberra'},
#  {'US': 'Boston'},
#  {'US': 'Washington'},
#  {'AU': 'Subiaco'},
#  {'US': 'Washington'},
#  {'GB': 'London'},
#  {'US': 'Seattle'},
#  {'US': 'Charlotte'},
#  {'US': 'Houston'},
#  {'US': 'Charlotte'},
#  {'US': 'Las Vegas'},
#  {'AU': 'Sydney'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Perth'},
#  {'GB': 'Glasgow'},
#  {'AU': 'Sydney'},
#  {'AU': 'Sydney'},
#  {'AU': 'Perth'},
#  {'AU': 'Perth'},
#  {'US': 'Detroit'},
#  {'US': 'Washington'},
#  {'US': 'Las Vegas'},
#  {'AU': 'Brisbane'},
#  {'US': 'Seattle'},
#  {'AU': 'Perth'},
#  {'AU': 'Perth'},
#  {'US': 'Houston'},
#  {'US': 'Boston'},
#  {'US': 'New York'},
#  {'AU': 'Canberra'},
#  {'US': 'Phoenix'},
#  {'US': 'Houston'},
#  {'AU': 'Perth'},
#  {'GB': 'London'},
#  {'AU': 'Brisbane'},
#  {'US': 'Denver'},
#  {'US': 'Birmingham'},
#  {'US': 'Birmingham'},
#  {'GB': 'Glasgow'},
#  {'US': 'Boston'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Detroit'},
#  {'US': 'Las Vegas'},
#  {'US': 'Chicago'},
#  {'US': 'Detroit'},
#  {'US': 'Detroit'},
#  {'US': 'Detroit'},
#  {'AU': 'Perth'},
#  {'US': 'Las Vegas'},
#  {'GB': 'Glasgow'},
#  {'US': 'Boston'},
#  {'US': 'San Jose'},
#  {'AU': 'Phillip'},
#  {'US': 'Birmingham'},
#  {'US': 'New York'},
#  {'AU': 'Canberra'},
#  {'AU': 'Sydney'},
#  {'GB': 'London'},
#  {'US': 'Boston'},
#  {'AU': 'Sydney'},
#  {'US': 'Detroit'},
#  {'US': 'Boston'},
#  {'US': 'Brooklyn'},
#  {'GB': 'London'},
#  {'US': 'Denver'},
#  {'AU': 'Brisbane'},
#  {'AU': 'Dickson'},
#  {'AU': 'Griffith'},
#  {'GB': 'Glasgow'},
#  {'US': 'Boston'},
#  {'US': 'New York'},
#  {'AU': 'Sydney'},
#  {'AU': 'Perth'},
#  {'US': 'Denver'},
#  {'AU': 'Braddon'},
#  {'US': 'Detroit'},
#  {'US': 'Boston'},
#  {'GB': 'Glasgow'},
#  {'US': 'Denver'},
#  {'US': 'Chicago'},
#  {'GB': 'Glasgow'},
#  {'US': 'Houston'},
#  {'AU': 'Sydney'},
#  {'US': 'Boston'},
#  {'AU': 'Sydney'},
#  {'US': 'Houston'},
#  {'US': 'Brooklyn'},
#  {'AU': 'Melbourne'},
#  {'US': 'San Francisco'},
#  {'US': 'San Francisco'},
#  {'US': 'Houston'},
#  {'US': 'Boston'},
#  {'GB': 'London'},
#  {'US': 'Washington'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'New York'},
#  {'US': 'Seattle'},
#  {'US': 'Brooklyn'},
#  {'US': 'Washington'},
#  {'AU': 'Sydney'},
#  {'US': 'Houston'},
#  {'US': 'Brooklyn'},
#  {'AU': 'Melbourne'},
#  {'US': 'Boston'},
#  {'US': 'Seattle'},
#  {'AU': 'Perth'},
#  {'GB': 'Glasgow'},
#  {'US': 'Houston'},
#  {'AU': 'Melbourne'},
#  {'GB': 'Liverpool'},
#  {'GB': 'Glasgow'},
#  {'US': 'Las Vegas'},
#  {'US': 'Las Vegas'},
#  {'US': 'San Jose'},
#  {'US': 'Las Vegas'},
#  {'GB': 'Glasgow'},
#  {'GB': 'Liverpool'},
#  {'US': 'Las Vegas'},
#  {'US': 'Las Vegas'},
#  {'US': 'Washington'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Houston'},
#  {'US': 'San Francisco'},
#  {'US': 'Las Vegas'},
#  {'AU': 'Melbourne'},
#  {'US': 'Charlotte'},
#  {'US': 'Denver'},
#  {'US': 'Washington'},
#  {'US': 'Las Vegas'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Melbourne'},
#  {'US': 'Las Vegas'},
#  {'US': 'Las Vegas'},
#  {'US': 'Charlotte'},
#  {'US': 'Detroit'},
#  {'AU': 'Sydney'},
#  {'GB': 'London'},
#  {'US': 'Seattle'},
#  {'AU': 'Canberra'},
#  {'GB': 'London'},
#  {'US': 'Las Vegas'},
#  {'AU': 'Sydney'},
#  {'US': 'Detroit'},
#  {'US': 'Denver'},
#  {'US': 'Charlotte'},
#  {'GB': 'London'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'GB': 'London'},
#  {'AU': 'Perth'},
#  {'US': 'Boston'},
#  {'US': 'Detroit'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'US': 'Seattle'},
#  {'US': 'San Jose'},
#  {'GB': 'Glasgow'},
#  {'AU': 'Brisbane'},
#  {'GB': 'London'},
#  {'US': 'Chicago'},
#  {'US': 'Seattle'},
#  {'US': 'Chicago'},
#  {'AU': 'Sydney'},
#  {'US': 'Washington'},
#  {'AU': 'Perth'},
#  {'US': 'Boston'},
#  {'US': 'San Jose'},
#  {'US': 'San Jose'},
#  {'AU': 'Sydney'},
#  {'US': 'Phoenix'},
#  {'US': 'Boston'},
#  {'US': 'Seattle'},
#  {'US': 'Houston'},
#  {'US': 'Boston'},
#  {'GB': 'London'},
#  {'AU': 'Perth'},
#  {'AU': 'Sydney'},
#  {'US': 'Seattle'},
#  {'US': 'Washington'},
#  {'US': 'Washington'},
#  {'US': 'Seattle'},
#  {'US': 'Seattle'},
#  {'US': 'Denver'},
#  {'GB': 'Liverpool'},
#  {'AU': 'Perth'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'US': 'Chicago'},
#  {'AU': 'Brisbane'},
#  {'AU': 'Sydney'},
#  {'US': 'New York'},
#  {'AU': 'Sydney'},
#  {'US': 'Chicago'},
#  {'GB': 'Glasgow'},
#  {'AU': 'Sydney'},
#  {'US': 'San Francisco'},
#  {'GB': 'Liverpool'},
#  {'GB': 'Glasgow'},
#  {'US': 'Washington'},
#  {'US': 'Washington'},
#  {'US': 'San Francisco'},
#  {'US': 'Washington'},
#  {'GB': 'London'},
#  {'AU': 'Sydney'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Seattle'},
#  {'GB': 'Glasgow'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'AU': 'Sydney'},
#  {'US': 'Charlotte'},
#  {'US': 'Phoenix'},
#  {'US': 'Phoenix'},
#  {'AU': 'Sydney'},
#  {'AU': 'Braddon'},
#  {'US': 'Houston'},
#  {'US': 'Phoenix'},
#  {'US': 'Houston'},
#  {'US': 'Birmingham'},
#  {'US': 'Charlotte'},
#  {'AU': 'Perth'},
#  {'AU': 'Sydney'},
#  {'US': 'Boston'},
#  {'US': 'Seattle'},
#  {'GB': 'London'},
#  {'AU': 'Sydney'},
#  {'US': 'Brooklyn'},
#  {'GB': 'London'},
#  {'US': 'Boston'},
#  {'GB': 'Glasgow'},
#  {'US': 'Denver'},
#  {'AU': 'Sydney'},
#  {'US': 'Chicago'},
#  {'US': 'Detroit'},
#  {'US': 'Houston'},
#  {'US': 'Las Vegas'},
#  {'US': 'Seattle'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'AU': 'Sydney'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'AU': 'Melbourne'},
#  {'US': 'Houston'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Melbourne'},
#  {'US': 'New York'},
#  {'AU': 'Brisbane'},
#  {'US': 'Chicago'},
#  {'GB': 'London'},
#  {'AU': 'Fyshwick'},
#  {'AU': 'Brisbane'},
#  {'AU': 'Canberra City'},
#  {'AU': 'Perth'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Denver'},
#  {'US': 'Brooklyn'},
#  {'US': 'Denver'},
#  {'US': 'Chicago'},
#  {'US': 'Chicago'},
#  {'US': 'Washington'},
#  {'US': 'Charlotte'},
#  {'US': 'Detroit'},
#  {'US': 'Las Vegas'},
#  {'US': 'Houston'},
#  {'AU': 'Melbourne'},
#  {'US': 'Phoenix'},
#  {'US': 'San Jose'},
#  {'AU': 'Kingston'},
#  {'US': 'Washington'},
#  {'US': 'Brooklyn'},
#  {'AU': 'Melbourne'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Chicago'},
#  {'AU': 'Perth'},
#  {'GB': 'London'},
#  {'US': 'Detroit'},
#  {'AU': 'Rosebery'},
#  {'AU': 'Perth'},
#  {'GB': 'London'},
#  {'GB': 'Glasgow'},
#  {'US': 'Charlotte'},
#  {'GB': 'Liverpool'},
#  {'US': 'Chicago'},
#  {'AU': 'Belconnen'},
#  {'US': 'Detroit'},
#  {'US': 'Detroit'},
#  {'US': 'Detroit'},
#  {'AU': 'Melbourne'},
#  {'US': 'Birmingham'},
#  {'AU': 'Perth'},
#  {'US': 'Houston'},
#  {'AU': 'Canberra'},
#  {'AU': 'Manuka'},
#  {'AU': 'Phillip'},
#  {'US': 'Chicago'},
#  {'AU': 'Perth'},
#  {'US': 'New York'},
#  {'US': 'Boston'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'AU': 'Melbourne'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'AU': 'Sydney'},
#  {'US': 'Charlotte'},
#  {'US': 'Washington'},
#  {'AU': 'Yarralumla'},
#  {'AU': 'Sydney'},
#  {'US': 'San Francisco'},
#  {'US': 'New York'},
#  {'AU': 'Melbourne'},
#  {'US': 'Boston'},
#  {'US': 'Houston'},
#  {'US': 'Charlotte'},
#  {'GB': 'London'},
#  {'AU': 'Perth'},
#  {'AU': 'Sydney'},
#  {'US': 'Detroit'},
#  {'US': 'San Jose'},
#  {'GB': 'London'},
#  {'US': 'Houston'},
#  {'US': 'Boston'},
#  {'AU': 'Canberra'},
#  {'US': 'Birmingham'},
#  {'AU': 'Perth'},
#  {'US': 'Seattle'},
#  {'US': 'Washington'},
#  {'US': 'Detroit'},
#  {'GB': 'Liverpool'},
#  {'US': 'New York'},
#  {'US': 'Seattle'},
#  {'GB': 'London'},
#  {'GB': 'Glasgow'},
#  {'US': 'San Jose'},
#  {'US': 'Chicago'},
#  {'US': 'Denver'},
#  {'US': 'Chicago'},
#  {'GB': 'London'},
#  {'US': 'Birmingham'},
#  {'US': 'Houston'},
#  {'AU': 'Sydney'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Melbourne'},
#  {'US': 'Detroit'},
#  {'US': 'San Jose'},
#  {'NZ': 'Auckland'},
#  {'AU': 'Melbourne'},
#  {'US': 'Denver'},
#  {'US': 'San Jose'},
#  {'US': 'Las Vegas'},
#  {'US': 'Denver'},
#  {'US': 'Denver'},
#  {'US': 'San Jose'},
#  {'US': 'San Jose'},
#  {'US': 'San Jose'},
#  {'US': 'San Jose'},
#  {'US': 'San Jose'},
#  {'GB': 'Glasgow'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'US': 'Denver'},
#  {'US': 'Birmingham'},
#  {'US': 'Boston'},
#  {'US': 'New York'},
#  {'US': 'Seattle'},
#  {'US': 'San Jose'},
#  {'US': 'San Francisco'},
#  {'US': 'Washington'},
#  {'AU': 'Perth'},
#  {'US': 'Birmingham'},
#  {'US': 'Seattle'},
#  {'US': 'Seattle'},
#  {'US': 'Boston'},
#  {'US': 'Houston'},
#  {'US': 'Birmingham'},
#  {'US': 'Detroit'},
#  {'AU': 'Melbourne'},
#  {'US': 'Washington'},
#  {'US': 'Boston'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'AU': 'Sydney'},
#  {'GB': 'Liverpool'},
#  {'AU': 'Perth'},
#  {'GB': 'Liverpool'},
#  {'US': 'Charlotte'},
#  {'US': 'Houston'},
#  {'GB': 'Liverpool'},
#  {'AU': 'Sydney'},
#  {'GB': 'Liverpool'},
#  {'US': 'San Francisco'},
#  {'US': 'San Jose'},
#  {'US': 'Seattle'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'AU': 'Melbourne'},
#  {'US': 'Washington'},
#  {'AU': 'Sydney'},
#  {'US': 'Las Vegas'},
#  {'US': 'Chicago'},
#  {'US': 'San Francisco'},
#  {'AU': 'Kingston'},
#  {'AU': 'Northbridge'},
#  {'US': 'Las Vegas'},
#  {'GB': 'London'},
#  {'US': 'San Jose'},
#  {'US': 'Washington'},
#  {'US': 'Brooklyn'},
#  {'US': 'Seattle'},
#  {'AU': 'Sydney'},
#  {'US': 'Las Vegas'},
#  {'US': 'Seattle'},
#  {'US': 'New York'},
#  {'GB': 'Glasgow'},
#  {'US': 'Birmingham'},
#  {'US': 'Birmingham'},
#  {'US': 'Birmingham'},
#  {'US': 'Birmingham'},
#  {'AU': 'Belconnen'},
#  {'AU': 'Melbourne'},
#  {'GB': 'London'},
#  {'US': 'Boston'},
#  {'AU': 'Sydney'},
#  {'AU': 'Perth'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Seattle'},
#  {'AU': 'Braddon'},
#  {'GB': 'London'},
#  {'US': 'Boston'},
#  {'US': 'Washington'},
#  {'US': 'Houston'},
#  {'US': 'Birmingham'},
#  {'US': 'Chicago'},
#  {'US': 'Houston'},
#  {'GB': 'Liverpool'},
#  {'AU': 'Melbourne'},
#  {'US': 'Phoenix'},
#  {'AU': 'Sydney'},
#  {'US': 'Boston'},
#  {'US': 'Charlotte'},
#  {'GB': 'London'},
#  {'US': 'Long Island City'},
#  {'GB': 'London'},
#  {'US': 'Detroit'},
#  {'US': 'Phoenix'},
#  {'GB': 'Glasgow'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Newtown'},
#  {'GB': 'London'},
#  {'US': 'Las Vegas'},
#  {'US': 'Boston'},
#  {'US': 'Washington'},
#  {'GB': 'London'},
#  {'US': 'Chicago'},
#  {'US': 'Boston'},
#  {'AU': 'Sydney'},
#  {'US': 'Phoenix'},
#  {'US': 'Denver'},
#  {'US': 'San Jose'},
#  {'AU': 'Melbourne'},
#  {'US': 'Birmingham'},
#  {'US': 'Denver'},
#  {'US': 'San Francisco'},
#  {'US': 'New York'},
#  {'US': 'San Jose'},
#  {'US': 'Detroit'},
#  {'US': 'San Jose'},
#  {'AU': 'Melbourne'},
#  {'US': 'Las Vegas'},
#  {'US': 'Las Vegas'},
#  {'AU': 'Sydney'},
#  {'US': 'Denver'},
#  {'US': 'San Jose'},
#  {'AU': 'Melbourne'},
#  {'US': 'Seattle'},
#  {'US': 'Birmingham'},
#  {'US': 'Boston'},
#  {'AU': 'Brisbane'},
#  {'US': 'Denver'},
#  {'US': 'Seattle'},
#  {'AU': 'Perth'},
#  {'US': 'Las Vegas'},
#  {'US': 'San Jose'},
#  {'AU': 'Perth'},
#  {'AU': 'Perth'},
#  {'US': 'Detroit'},
#  {'US': 'New York'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'GB': 'London'},
#  {'US': 'Las Vegas'},
#  {'US': 'San Jose'},
#  {'GB': 'London'},
#  {'US': 'Houston'},
#  {'US': 'Chicago'},
#  {'AU': 'Acton'},
#  {'US': 'Detroit'},
#  {'US': 'Boston'},
#  {'US': 'Birmingham'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Chicago'},
#  {'US': 'Houston'},
#  {'US': 'Seattle'},
#  {'US': 'Houston'},
#  {'AU': 'Braddon'},
#  {'AU': 'Dickson'},
#  {'AU': 'Kingston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'AU': 'Melbourne'},
#  {'GB': 'Glasgow'},
#  {'US': 'Houston'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Dickson'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Washington'},
#  {'AU': 'Sydney'},
#  {'GB': 'London'},
#  {'US': 'Denver'},
#  {'AU': 'Melbourne'},
#  {'US': 'Las Vegas'},
#  {'AU': 'Melbourne'},
#  {'US': 'Detroit'},
#  {'AU': 'Parkes'},
#  {'US': 'Charlotte'},
#  {'GB': 'London'},
#  {'US': 'Phoenix'},
#  {'GB': 'London'},
#  {'US': 'Washington'},
#  {'US': 'Las Vegas'},
#  {'US': 'Las Vegas'},
#  {'AU': 'Melbourne'},
#  {'US': 'Houston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'US': 'Boston'},
#  {'AU': 'Sydney'},
#  {'AU': 'Brisbane'},
#  {'GB': 'Glasgow'},
#  {'US': 'Birmingham'},
#  {'US': 'Birmingham'},
#  {'GB': 'London'},
#  {'AU': 'Melbourne'},
#  {'US': 'Las Vegas'},
#  {'US': 'Chicago'},
#  {'US': 'Seattle'},
#  {'US': 'San Francisco'},
#  {'US': 'Las Vegas'},
#  {'US': 'Charlotte'},
#  {'US': 'Washington'},
#  {'US': 'Washington'},
#  {'US': 'Denver'},
#  {'GB': 'Glasgow'},
#  {'AU': 'Sydney'},
#  {'AU': 'Melbourne'},
#  {'US': 'San Jose'},
#  {'AU': 'Perth'},
#  {'AU': 'Fyshwick'},
#  {'US': 'San Francisco'},
#  {'US': 'Washington'},
#  {'US': 'San Jose'},
#  {'AU': 'Sutton'},
#  {'US': 'Seattle'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'GB': 'London'},
#  {'AU': 'Melbourne'},
#  {'US': 'Birmingham'},
#  {'GB': 'London'},
#  {'US': 'San Jose'},
#  {'GB': 'London'},
#  {'US': 'San Jose'},
#  {'AU': 'Sydney'},
#  {'US': 'Chicago'},
#  {'US': 'Detroit'},
#  {'GB': 'Glasgow'},
#  {'AU': 'Perth'},
#  {'US': 'Washington'},
#  {'US': 'San Francisco'},
#  {'US': 'New York'},
#  {'GB': 'Glasgow'},
#  {'US': 'San Francisco'},
#  {'US': 'San Francisco'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Newtown'},
#  {'US': 'Chicago'},
#  {'US': 'Boston'},
#  {'US': 'Chicago'},
#  {'US': 'Brooklyn'},
#  {'US': 'Chicago'},
#  {'US': 'Chicago'},
#  {'AU': 'Melbourne'},
#  {'US': 'Seattle'},
#  {'US': 'New York'},
#  {'US': 'Birmingham'},
#  {'GB': 'London'},
#  {'US': 'Boston'},
#  {'US': 'Birmingham'},
#  {'US': 'Houston'},
#  {'US': 'Bronx'},
#  {'US': 'Washington'},
#  {'US': 'Houston'},
#  {'US': 'Brooklyn'},
#  {'US': 'Brooklyn'},
#  {'GB': 'Glasgow'},
#  {'US': 'Brooklyn'},
#  {'US': 'Houston'},
#  {'US': 'Houston'},
#  {'US': 'Brooklyn'},
#  {'US': 'Houston'},
#  {'US': 'Charlotte'},
#  {'US': 'Houston'},
#  {'AU': 'Melbourne'},
#  {'US': 'Houston'},
#  {'AU': 'Perth'},
#  {'US': 'Seattle'},
#  {'US': 'Boston'},
#  {'GB': 'Liverpool'},
#  {'US': 'Boston'},
#  {'AU': 'Bruce'},
#  {'AU': 'Melbourne'},
#  {'GB': 'London'},
#  {'US': 'San Francisco'},
#  {'US': 'Seattle'},
#  {'GB': 'Glasgow'},
#  {'GB': 'Glasgow'},
#  {'US': 'Las Vegas'},
#  {'US': 'Chicago'},
#  {'US': 'Washington'},
#  {'US': 'Houston'},
#  {'US': 'Denver'},
#  {'US': 'Detroit'},
#  {'US': 'Detroit'},
#  {'US': 'Detroit'},
#  {'US': 'Birmingham'},
#  {'US': 'Las Vegas'},
#  {'GB': 'Glasgow'},
#  {'US': 'Detroit'},
#  {'GB': 'London'},
#  {'AU': 'Brisbane'},
#  {'AU': 'Darlinghurst'},
#  {'US': 'Detroit'},
#  {'US': 'Houston'},
#  {'GB': 'Liverpool'},
#  {'GB': 'London'},
#  {'US': 'Boston'},
#  {'US': 'Washington'},
#  {'US': 'Denver'},
#  {'AU': 'Brisbane'},
#  {'US': 'Houston'},
#  {'US': 'San Jose'},
#  {'GB': 'London'},
#  {'AU': 'Sydney'},
#  {'GB': 'Liverpool'},
#  {'AU': 'Milton'},
#  {'US': 'Washington'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'US': 'New York'},
#  {'GB': 'London'},
#  {'US': 'Las Vegas'},
#  {'US': 'San Jose'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Sydney'},
#  {'AU': 'Braddon'},
#  {'AU': 'Melbourne'},
#  {'US': 'Washington'},
#  {'US': 'Houston'},
#  {'US': 'Phoenix'},
#  {'AU': 'Brisbane'},
#  {'AU': 'Sydney'},
#  {'US': 'Seattle'},
#  {'AU': 'Melbourne'},
#  {'US': 'San Francisco'},
#  {'US': 'San Francisco'},
#  {'AU': 'Perth'},
#  {'US': 'San Jose'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'US': 'Washington'},
#  {'US': 'Washington'},
#  {'US': 'Houston'},
#  {'US': 'Chicago'},
#  {'US': 'Brooklyn'},
#  {'US': 'San Francisco'},
#  {'AU': 'Barton'},
#  {'US': 'New York'},
#  {'AU': 'Melbourne'},
#  {'US': 'Detroit'},
#  {'US': 'Seattle'},
#  {'GB': 'Liverpool'},
#  {'GB': 'London'},
#  {'GB': 'London'},
#  {'AU': 'Kingston'},
#  {'AU': 'Perth'},
#  {'AU': 'Melbourne'},
#  {'AU': 'Melbourne'},
#  {'US': 'Charlotte'},
#  ...]
